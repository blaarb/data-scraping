# %%
import requests

# %%
url = 'https://books.toscrape.com/'
headers = {
    'User-Agent': 'my user agnet mozilla'
}
response = requests.get(url)
if response.status_code == 200:
    print(response.content)
else:
    print(f'Ошибка: {response.status_code}')
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" href="static/oscar/favicon.ico" />\n        \n\n        \n        \n    \n    \n        <link rel="stylesheet" type="text/css" href="static/oscar/css/styles.css" />\n    \n    <link rel="stylesheet" href="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css" />\n    <link rel="stylesheet" type="text/css" href="static/oscar/css/datetimepicker.css" />\n\n\n        \n        \n\n        \n\n        \n            \n            \n\n        \n    </head>\n\n    <body id="default" class="default">\n        \n        \n    \n    \n    <header class="header container-fluid">\n        <div class="page_inner">\n            <div class="row">\n                <div class="col-sm-8 h1"><a href="index.html">Books to Scrape</a><small> We love being scraped!</small>\n</div>\n\n                \n            </div>\n        </div>\n    </header>\n\n    \n    \n<div class="container-fluid page">\n    <div class="page_inner">\n        \n    <ul class="breadcrumb">\n        <li>\n            <a href="index.html">Home</a>\n        </li>\n        <li class="active">All products</li>\n    </ul>\n\n        <div class="row">\n\n            <aside class="sidebar col-sm-4 col-md-3">\n                \n                <div id="promotions_left">\n                    \n                </div>\n                \n    \n    \n        \n        <div class="side_categories">\n            <ul class="nav nav-list">\n                \n                    <li>\n                        <a href="catalogue/category/books_1/index.html">\n                            \n                                Books\n                            \n                        </a>\n\n                        <ul>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/travel_2/index.html">\n                            \n                                Travel\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/mystery_3/index.html">\n                            \n                                Mystery\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/historical-fiction_4/index.html">\n                            \n                                Historical Fiction\n                            \n                        </a>\n\n                        </li>\n                        \n                \n                    <li>\n                        <a href="catalogue/category/books/sequential-art_5/index.html">\n                            \n                                Sequential Art\n                            \n                        </a>\n\n                        </li>\n           ...

# %%
link = 'https://api.openweathermap.org/data/2.5/weather?q=Moscow&appid=9d8daa41b29a6b976af2c3e0eb804272&'
r = requests.get(link)
r.status_code
# Out:
# 200

# %%
link = 'https://api.openweathermap.org/data/2.5/weather'
params = {
    'q': 'Moscow',
    'appid': '9d8daa41b29a6b976af2c3e0eb804272'
}
response = requests.get(link, params=params)

# %%
url = 'https://api.hh.ru/vacancies'
params = {
    'text': 'Data Science'
}
r = requests.get(url, params=params)
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'items': [{'id': '49423067',
#    'premium': False,
#    'name': 'Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 380000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-06T13:20:11+0300',
#    'created_at': '2022-06-06T13:20:11+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49423067',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49423067?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/49423067/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49423067',
#    'relations': [],
#    'employer': {'id': '2324020',
#     'name': 'Точка',
#     'url': 'https://api.hh.ru/employers/2324020',
#     'alternate_url': 'https://hh.ru/employer/2324020',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3414734.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3414733.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/743443.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2324020',
#     'trusted': True},
#    'snippet': {'requirement': 'Есть опыт работы с методами машинного обучения и основными инструментами <highlighttext>data</highlighttext> <highlighttext>science</highlighttext>: Scikit-learn, XGBoost, CatBoost. Разбираешься в математической статистике...',
#     'responsibility': 'Придумывать и проверять гипотезы, которые позволят улучшить и оптимизировать внутренние процессы в Точке. Будешь доставать данные из баз и других...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66511453',
#    'premium': False,
#    'name': 'Data scientist в международный стартап',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 200000, 'to': 250000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-04T12:59:38+0300',
#    'created_at': '2022-06-04T12:59:38+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66511453',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66511453?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66511453/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66511453',
#    'relations': [],
#    'employer': {'id': '3306967',
#     'name': 'Mind&Machine',
#     'url': 'https://api.hh.ru/employers/3306967',
#     'alternate_url': 'https://hh.ru/employer/3306967',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/948233.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/4233469.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/4233468.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3306967',
#     'trusted': True},
#    'snippet': {'requirement': 'Ключевые навыки:\u200d\u200d. — Умение общаться с клиентами и понимать их бизнес-процессы. — Знание Python, в том числе numpy, scipy, pandas, scikit...',
#     'responsibility': 'анализ процессов клиентов. — прогнозирование временных рядов: потока клиентов, объёма операций, построение иерархических временных рядов. — разработка и улучшение алгоритмов дискретной оптимизации.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True},
#   {'id': '66632053',
#    'premium': False,
#    'name': 'Senior Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 4000, 'to': 5000, 'currency': 'USD', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-06T14:58:46+0300',
#    'created_at': '2022-06-06T14:58:46+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66632053',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66632053?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66632053/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66632053',
#    'relations': [],
#    'employer': {'id': '4955407',
#     'name': 'Top Remote Talent',
#     'url': 'https://api.hh.ru/employers/4955407',
#     'alternate_url': 'https://hh.ru/employer/4955407',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3954496.png',
#      '90': 'https://hhcdn.ru/employer-logo/3954495.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/878405.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4955407',
#     'trusted': True},
#    'snippet': {'requirement': 'Requirements: At least 5 years of experience in <highlighttext>data</highlighttext> <highlighttext>science</highlighttext>. Strong background in Machine Learning (Logistic Regression, Gradient Boosting Trees...',
#     'responsibility': 'Competitive salary.'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True},
#   {'id': '54882705',
#    'premium': False,
#    'name': 'Junior Data scientist/ Младший риск-аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': True,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица 8 Марта',
#     'building': '1с12',
#     'description': None,
#     'lat': 55.800726,
#     'lng': 37.554933,
#     'raw': 'Москва, улица 8 Марта, 1с12',
#     'metro': {'station_name': 'Динамо',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.34',
#      'line_id': '2',
#      'lat': 55.789704,
#      'lng': 37.558212},
#     'metro_stations': [{'station_name': 'Динамо',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.34',
#       'line_id': '2',
#       'lat': 55.789704,
#       'lng': 37.558212},
#      {'station_name': 'Петровский парк',
#       'line_name': 'Большая кольцевая линия',
#       'station_id': '97.599',
#       'line_id': '97',
#       'lat': 55.79233,
#       'lng': 37.55952}],
#     'id': '1551673'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-05T11:54:00+0300',
#    'created_at': '2022-06-05T11:54:00+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=54882705',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/54882705?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/54882705/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/54882705',
#    'relations': [],
#    'employer': {'id': '1039977',
#     'name': 'Pay P.S.',
#     'url': 'https://api.hh.ru/employers/1039977',
#     'alternate_url': 'https://hh.ru/employer/1039977',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1071075.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/89627.png',
#      '90': 'https://hhcdn.ru/employer-logo/1071074.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1039977',
#     'trusted': True},
#    'snippet': {'requirement': 'Умение работать в команде, открытость к новым идеям и технологиям, желание расти и развиваться в направлении <highlighttext>data</highlighttext> <highlighttext>science</highlighttext>. ',
#     'responsibility': 'Несколько сайтов с посещаемостью около 1 млн. посещений в месяц. Большое количество партнеров (телеком операторы, банки, интернет-магазины, онлайн кассы...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66615417',
#    'premium': False,
#    'name': 'Аналитик данных (Data Scientist)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '159',
#     'name': 'Нур-Султан',
#     'url': 'https://api.hh.ru/areas/159'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-06T10:33:51+0300',
#    'created_at': '2022-06-06T10:33:51+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66615417',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66615417?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66615417/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66615417',
#    'relations': [],
#    'employer': {'id': '1038826',
#     'name': 'Business and Technology Services',
#     'url': 'https://api.hh.ru/employers/1038826',
#     'alternate_url': 'https://hh.ru/employer/1038826',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3380269.png',
#      '240': 'https://hhcdn.ru/employer-logo/3380270.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/734823.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1038826',
#     'trusted': True},
#    'snippet': {'requirement': 'Отличный математический и технический бекграунд в статистике, анализе данных и ML. Владение Python стеком анализа данных и моделирование (pandas, numpy...',
#     'responsibility': 'Собственная разработка и внедрение решений промышленного ИИ. Использование методов анализа данных и машинного обучения для. Выявления и прогнозирование отклонений в...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55567683',
#    'premium': False,
#    'name': 'Аналитик данных / Data Scientist',
#    'department': None,
#    'has_test': True,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Новодмитровская улица',
#     'building': '2к1',
#     'description': None,
#     'lat': 55.804936,
#     'lng': 37.589922,
#     'raw': 'Москва, Новодмитровская улица, 2к1',
#     'metro': {'station_name': 'Дмитровская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.35',
#      'line_id': '9',
#      'lat': 55.808056,
#      'lng': 37.581734},
#     'metro_stations': [{'station_name': 'Дмитровская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.35',
#       'line_id': '9',
#       'lat': 55.808056,
#       'lng': 37.581734}],
#     'id': '721759'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-03T17:59:59+0300',
#    'created_at': '2022-06-03T17:59:59+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55567683',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55567683?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55567683/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55567683',
#    'relations': [],
#    'employer': {'id': '779',
#     'name': 'ЭКОПСИ Консалтинг',
#     'url': 'https://api.hh.ru/employers/779',
#     'alternate_url': 'https://hh.ru/employer/779',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/233351.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/677514.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/677513.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=779',
#     'trusted': True},
#    'snippet': {'requirement': 'Образование высшее: социальные <highlighttext>науки</highlighttext> (психология / социология / экономика) или IT / математика / физика. Знание английского (чтение профессиональной литературы). Высокий уровень самостоятельности и...',
#     'responsibility': 'Анализ результатов проектов и разработка рекомендаций по улучшению оценочных инструментов. Работа с психометрическими данными, внедрение IRT в тесты. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66589868',
#    'premium': False,
#    'name': 'Researcher Data Science',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-03T16:31:08+0300',
#    'created_at': '2022-06-03T16:31:08+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66589868',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66589868?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66589868/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66589868',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Магистратура исследовательской направленности в области компьютерных <highlighttext>наук</highlighttext>, статистики, математики или другой релевантной области. Не менее года опыта проведение академических или...',
#     'responsibility': 'Обзор множества научных статей, алгоритмов, моделей и кода, а также оценка их применимости в рамках рассматриваемой проблемы. Создание промышленных образцов...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55145641',
#    'premium': False,
#    'name': 'Junior Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': {'from': 50000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Санкт-Петербург',
#     'street': 'Московский проспект',
#     'building': '158Б',
#     'description': None,
#     'lat': 59.880013,
#     'lng': 30.322812,
#     'raw': 'Санкт-Петербург, Московский проспект, 158Б',
#     'metro': None,
#     'metro_stations': [],
#     'id': '725652'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-03T10:53:00+0300',
#    'created_at': '2022-06-03T10:53:00+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55145641',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55145641?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55145641/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55145641',
#    'relations': [],
#    'employer': {'id': '40938',
#     'name': 'Улыбка радуги',
#     'url': 'https://api.hh.ru/employers/40938',
#     'alternate_url': 'https://hh.ru/employer/40938',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3556364.png',
#      '90': 'https://hhcdn.ru/employer-logo/3556363.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/778868.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=40938',
#     'trusted': True},
#    'snippet': {'requirement': 'Владение SQL, Python (numpy, pandas, sklearn)/R. Знание статистики (в частности методов анализа временных рядов), алгоритмов машинного обучения (с учителем...',
#     'responsibility': 'Подготовка и очистка данных. Анализ данных на предмет выявления закономерностей. Разработка и внедрение статистических моделей и моделей, основанных на машинном...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55867764',
#    'premium': False,
#    'name': 'Senior Data Analyst',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Санкт-Петербург',
#     'street': 'Чкаловский проспект',
#     'building': '50',
#     'description': None,
#     'lat': 59.967358,
#     'lng': 30.299339,
#     'raw': 'Санкт-Петербург, Чкаловский проспект, 50',
#     'metro': None,
#     'metro_stations': [],
#     'id': '3299585'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-04T15:42:28+0300',
#    'created_at': '2022-06-04T15:42:28+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55867764',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55867764?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55867764/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55867764',
#    'relations': [],
#    'employer': {'id': '4295296',
#     'name': 'Софтвайс',
#     'url': 'https://api.hh.ru/employers/4295296',
#     'alternate_url': 'https://hh.ru/employer/4295296',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/683981.png',
#      '240': 'https://hhcdn.ru/employer-logo/3177057.png',
#      '90': 'https://hhcdn.ru/employer-logo/3177056.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4295296',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт исследовательской деятельности в роли <highlighttext>Data</highlighttext> Analyst/<highlighttext>Data</highlighttext> <highlighttext>Science</highlighttext>, направленной на выявление проблем, от 2х лет. Умение выделять суть...',
#     'responsibility': 'Искать слабые места системы и предлагать идеи по их модернизации. Вычленять задачи из проблем, декомпозировать и предлагать варианты решения и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66627658',
#    'premium': False,
#    'name': 'ML Engineer/Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1002',
#     'name': 'Минск',
#     'url': 'https://api.hh.ru/areas/1002'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-06T13:38:31+0300',
#    'created_at': '2022-06-06T13:38:31+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66627658',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66627658?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66627658/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66627658',
#    'relations': [],
#    'employer': {'id': '744104',
#     'name': 'Gurtam',
#     'url': 'https://api.hh.ru/employers/744104',
#     'alternate_url': 'https://hh.ru/employer/744104',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2247496.png',
#      '90': 'https://hhcdn.ru/employer-logo/2247495.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/451382.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=744104',
#     'trusted': True},
#    'snippet': {'requirement': 'Визуализация данных: bokeh/plotly, matplotlib, seaborn. Опыт работы с big <highlighttext>data</highlighttext> (Dask, PySpark). Практический опыт разработки AI/ML алгоритмами. ',
#     'responsibility': 'Построение, валидация и имплементация передовых алгоритмов машинного обучения в сфере телематики и IoT, например: Анализ больших объемов структурированной информации для...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66568751',
#    'premium': False,
#    'name': 'Стажер-Аналитик',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-03T11:24:15+0300',
#    'created_at': '2022-06-03T11:24:15+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66568751',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66568751?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66568751/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66568751',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'СБЕР',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Обучение на 4 курсе бакалавриата или 1-2 курсе магистратуры. - Английский (Upper Intermediate и выше). - Грамотный русский язык. - ',
#     'responsibility': 'Подготовка аналитических материалов и презентаций по теме <highlighttext>Data</highlighttext> <highlighttext>Science</highlighttext> и Artificial Intelligence. - Подготовка обзоров статей, представленных на ведущих международных конференциях...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55358460',
#    'premium': False,
#    'name': 'Data engineer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 3000, 'to': None, 'currency': 'USD', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-05T19:12:55+0300',
#    'created_at': '2022-06-05T19:12:55+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55358460',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55358460?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55358460/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55358460',
#    'relations': [],
#    'employer': {'id': '4715215',
#     'name': 'T-DIGITAL',
#     'url': 'https://api.hh.ru/employers/4715215',
#     'alternate_url': 'https://hh.ru/employer/4715215',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3435002.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3435001.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/748510.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4715215',
#     'trusted': True},
#    'snippet': {'requirement': 'Был опыт разработки решений для финансового сектора – как плюс. Есть знания в <highlighttext>Data</highlighttext> <highlighttext>Science</highlighttext> (статистика, теория вероятностей, вычислительные методы, алгоритмы...',
#     'responsibility': 'Формирование требований к новым программным приложениям и хранилищам данных. Обучение команды <highlighttext>data</highlighttext> <highlighttext>science</highlighttext> аналитиков и разработчиков по работе с хранилищем...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55529384',
#    'premium': False,
#    'name': 'Математик, Junior/Middle/Senior Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1002',
#     'name': 'Минск',
#     'url': 'https://api.hh.ru/areas/1002'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Минск',
#     'street': 'улица Платонова',
#     'building': '38',
#     'description': None,
#     'lat': 53.913592,
#     'lng': 27.602399,
#     'raw': 'Минск, улица Платонова, 38',
#     'metro': {'station_name': 'Академия наук',
#      'line_name': 'Московская',
#      'station_id': '62.407',
#      'line_id': '62',
#      'lat': 53.92187,
#      'lng': 27.599066},
#     'metro_stations': [{'station_name': 'Академия наук',
#       'line_name': 'Московская',
#       'station_id': '62.407',
#       'line_id': '62',
#       'lat': 53.92187,
#       'lng': 27.599066}],
#     'id': '2794644'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-05T16:55:35+0300',
#    'created_at': '2022-06-05T16:55:35+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55529384',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55529384?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55529384/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55529384',
#    'relations': [],
#    'employer': {'id': '1688252',
#     'name': 'Представительство ООО «Квалитет» (Российская Федерация) в РБ',
#     'url': 'https://api.hh.ru/employers/1688252',
#     'alternate_url': 'https://hh.ru/employer/1688252',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2602793.png',
#      '240': 'https://hhcdn.ru/employer-logo/2602794.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/540330.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1688252',
#     'trusted': False},
#    'snippet': {'requirement': 'высшее образование, квалификация «математик» («физик»). - знание методов, подходов и инструментов <highlighttext>Data</highlighttext> <highlighttext>Science</highlighttext>. - математическое моделирование на языке Python и статистический анализ...',
#     'responsibility': 'Предстоит работа с анализом поступающих данных с системы установленной на стенде. Проверка гипотез. - статистический анализ электрофизических измерений параметров многофазных потоков. - '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '53088820',
#    'premium': False,
#    'name': 'Data-analyst (удаленно)',
#    'department': {'id': 'bil-4934-it', 'name': 'билайн: ИТ, Data, Digital'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-05T10:57:35+0300',
#    'created_at': '2022-06-05T10:57:35+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=53088820',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/53088820?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/53088820/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/53088820',
#    'relations': [],
#    'employer': {'id': '4934',
#     'name': 'билайн',
#     'url': 'https://api.hh.ru/employers/4934',
#     'alternate_url': 'https://hh.ru/employer/4934',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/902351.png',
#      '90': 'https://hhcdn.ru/employer-logo/4050091.png',
#      '240': 'https://hhcdn.ru/employer-logo/4050092.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4934',
#     'trusted': True},
#    'snippet': {'requirement': 'Мы рассчитываем, что у тебя есть опыт и знания для этой позиции: Опыт работы аналитиком от 2 лет. ',
#     'responsibility': '...ad-hoc аналитика. Разработка новых метрик. Взаимодействие с заказчиком. Разработка проектных документов. Тесное взаимодействие с командой разработки и <highlighttext>Data</highlighttext> <highlighttext>Science</highlighttext>.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55258362',
#    'premium': False,
#    'name': 'Data Scientist',
#    'department': {'id': '89798-89798-04', 'name': 'МТС. Маркетинг'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1002',
#     'name': 'Минск',
#     'url': 'https://api.hh.ru/areas/1002'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Минск',
#     'street': 'пр. Независимости',
#     'building': '95',
#     'description': None,
#     'lat': 53.925741,
#     'lng': 27.616512,
#     'raw': 'Минск, пр. Независимости, 95',
#     'metro': {'station_name': 'Парк Челюскинцев',
#      'line_name': 'Московская',
#      'station_id': '62.406',
#      'line_id': '62',
#      'lat': 53.924214,
#      'lng': 27.613646},
#     'metro_stations': [{'station_name': 'Парк Челюскинцев',
#       'line_name': 'Московская',
#       'station_id': '62.406',
#       'line_id': '62',
#       'lat': 53.924214,
#       'lng': 27.613646}],
#     'id': '70052'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-03T16:00:30+0300',
#    'created_at': '2022-06-03T16:00:30+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55258362',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55258362?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55258362/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55258362',
#    'relations': [],
#    'employer': {'id': '89798',
#     'name': 'Мобильные ТелеСистемы (МТС), Беларусь',
#     'url': 'https://api.hh.ru/employers/89798',
#     'alternate_url': 'https://hh.ru/employer/89798',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3243320.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3243321.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/700551.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=89798',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание SQL. Знание Python. Опыт работы в Machine Learning, <highlighttext>Data</highlighttext> <highlighttext>Science</highlighttext> или профильное образование (в области ML). Знания в области...',
#     'responsibility': 'Работа со структурированными источниками данных (табличные данные). Формирование требований на развитие источников данных, участие в интеграции новых источников данных. '},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55499148',
#    'premium': False,
#    'name': 'Специалист Data Science (R)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '3',
#     'name': 'Екатеринбург',
#     'url': 'https://api.hh.ru/areas/3'},
#    'salary': {'from': 100000, 'to': 120000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Екатеринбург',
#     'street': 'Кировский район, микрорайон Втузгородок, Академическая улица',
#     'building': '18',
#     'description': None,
#     'lat': 56.850594,
#     'lng': 60.652245,
#     'raw': 'Екатеринбург, Кировский район, микрорайон Втузгородок, Академическая улица, 18',
#     'metro': None,
#     'metro_stations': [],
#     'id': '6392969'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-03T06:52:21+0300',
#    'created_at': '2022-06-03T06:52:21+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55499148',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55499148?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55499148/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55499148',
#    'relations': [],
#    'employer': {'id': '149191',
#     'name': 'Сталепромышленная компания',
#     'url': 'https://api.hh.ru/employers/149191',
#     'alternate_url': 'https://hh.ru/employer/149191',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/200648.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/414128.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/341271.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=149191',
#     'trusted': True},
#    'snippet': {'requirement': 'Образование высшее математическое или техническое (предпочтительно. МатМех УрФУ). Опыт разработки решений на R (dataframe, dplyr), или. Python. Знание SQL, интерфейсов...',
#     'responsibility': 'Аналитическая обработка стат. данных (цепь поставок, продажи. Производство); Построение мат.моделей. Разработка, тестирование и развитие алгоритмов планирования цепи поставок.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66203799',
#    'premium': False,
#    'name': 'Senior Product manager (Data Science)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-05T17:08:32+0300',
#    'created_at': '2022-06-05T17:08:32+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66203799',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66203799?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66203799/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66203799',
#    'relations': [],
#    'employer': {'id': '2524797',
#     'name': 'inDriver',
#     'url': 'https://api.hh.ru/employers/2524797',
#     'alternate_url': 'https://hh.ru/employer/2524797',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/702160.png',
#      '90': 'https://hhcdn.ru/employer-logo/3249756.png',
#      '240': 'https://hhcdn.ru/employer-logo/3249757.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2524797',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы аналитиком данных или продуктовым аналитиком. Опыт работы с маркетплейсами, ценообразованием, системами рекомендаций.',
#     'responsibility': 'Координировать работу команд, взаимодействовать как с аналитиками, специалистами <highlighttext>data</highlighttext> <highlighttext>science</highlighttext>, разработчиками, так и с бизнес-заказчиками. Общаться с командой разработки...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '55485778',
#    'premium': False,
#    'name': 'Data Scientist (Marketplace Efficiency)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-04T19:03:23+0300',
#    'created_at': '2022-06-04T19:03:23+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55485778',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55485778?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55485778/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55485778',
#    'relations': [],
#    'employer': {'id': '2524797',
#     'name': 'inDriver',
#     'url': 'https://api.hh.ru/employers/2524797',
#     'alternate_url': 'https://hh.ru/employer/2524797',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/702160.png',
#      '90': 'https://hhcdn.ru/employer-logo/3249756.png',
#      '240': 'https://hhcdn.ru/employer-logo/3249757.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2524797',
#     'trusted': True},
#    'snippet': {'requirement': 'Ожидаем сильный математический background (алгебра, теория вероятностей, статистика). Конечно же нужно знать основные алгоритмы и метрики ML. Обязательно нужен Python...',
#     'responsibility': 'Искать инсайты в данных, формулировать и проверять гипотезы, выбирать, обучать и проверять модели ценообразования. Готовить дизайн экспериментов, запускать их, оценивать...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '66544490',
#    'premium': False,
#    'name': 'Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-02T14:15:11+0300',
#    'created_at': '2022-06-02T14:15:11+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66544490',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/66544490?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/66544490/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/66544490',
#    'relations': [],
#    'employer': {'id': '1310515',
#     'name': 'Zoon.ru',
#     'url': 'https://api.hh.ru/employers/1310515',
#     'alternate_url': 'https://hh.ru/employer/1310515',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/849582.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/3839204.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3839203.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1310515',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы со сложными языковыми моделями (Transformer, BERT, GPT, T5). Опыт работы с "классическим" NLP (как преимущество). Технический английский. ',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True},
#   {'id': '55462568',
#    'premium': False,
#    'name': 'Data Science Team Lead (to Cyprus)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '236', 'name': 'Кипр', 'url': 'https://api.hh.ru/areas/236'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2022-06-04T10:52:24+0300',
#    'created_at': '2022-06-04T10:52:24+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=55462568',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/55462568?host=hh.ru',
#    'adv_response_url': 'https://api.hh.ru/vacancies/55462568/adv_response?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/55462568',
#    'relations': [],
#    'employer': {'id': '3266823',
#     'name': 'Tango Me',
#     'url': 'https://api.hh.ru/employers/3266823',
#     'alternate_url': 'https://hh.ru/employer/3266823',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3750939.png',
#      '240': 'https://hhcdn.ru/employer-logo/3750940.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/827514.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3266823',
#     'trusted': True},
#    'snippet': {'requirement': '5 Experience in hands on <highlighttext>data</highlighttext> <highlighttext>science</highlighttext> modeling, specifically in big <highlighttext>data</highlighttext> environments. Experience with real time environments - an advantage. ',
#     'responsibility': 'Manage and guide the team throughout the full <highlighttext>data</highlighttext> <highlighttext>science</highlighttext> cycle, from research to deployment and model use in production. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False}],
#  'found': 857,
#  'pages': 43,
#  'per_page': 20,
#  'page': 0,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?enable_snippets=true&text=Data+Science'}

# %%
import json
with open('hh_vacancies.json', 'w') as jf:
    json.dump(r.json(), jf)

# %%
url = 'https://api.hh.ru/vacancies?text=Data Science'
r = requests.get(url)
if r.status_code == 200:
    if 'items' in list(r.json().keys()):
        print(r.json().get('items'))
# Out:
# [{'id': '49423067', 'premium': False, 'name': 'Data Scientist', 'department': None, 'has_test': False, 'response_letter_required': False, 'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'}, 'salary': {'from': None, 'to': 380000, 'currency': 'RUR', 'gross': False}, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': None, 'response_url': None, 'sort_point_distance': None, 'published_at': '2022-06-06T13:20:11+0300', 'created_at': '2022-06-06T13:20:11+0300', 'archived': False, 'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49423067', 'insider_interview': None, 'url': 'https://api.hh.ru/vacancies/49423067?host=hh.ru', 'adv_response_url': 'https://api.hh.ru/vacancies/49423067/adv_response?host=hh.ru', 'alternate_url': 'https://hh.ru/vacancy/49423067', 'relations': [], 'employer': {'id': '2324020', 'name': 'Точка', 'url': 'https://api.hh.ru/employers/2324020', 'alternate_url': 'https://hh.ru/employer/2324020', 'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3414734.jpeg', '90': 'https://hhcdn.ru/employer-logo/3414733.jpeg', 'original': 'https://hhcdn.ru/employer-logo-original/743443.jpg'}, 'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2324020', 'trusted': True}, 'snippet': {'requirement': 'Есть опыт работы с методами машинного обучения и основными инструментами <highlighttext>data</highlighttext> <highlighttext>science</highlighttext>: Scikit-learn, XGBoost, CatBoost. Разбираешься в математической статистике...', 'responsibility': 'Придумывать и проверять гипотезы, которые позволят улучшить и оптимизировать внутренние процессы в Точке. Будешь доставать данные из баз и других...'}, 'contacts': None, 'schedule': {'id': 'fullDay', 'name': 'Полный день'}, 'working_days': [], 'working_time_intervals': [], 'working_time_modes': [], 'accept_temporary': False}, {'id': '66511453', 'premium': False, 'name': 'Data scientist в международный стартап', 'department': None, 'has_test': False, 'response_letter_required': False, 'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'}, 'salary': {'from': 200000, 'to': 250000, 'currency': 'RUR', 'gross': False}, 'type': {'id': 'open', 'name': 'Открытая'}, 'address': None, 'response_url': None, 'sort_point_distance': None, 'published_at': '2022-06-04T12:59:38+0300', 'created_at': '2022-06-04T12:59:38+0300', 'archived': False, 'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=66511453', 'insider_interview': None, 'url': 'https://api.hh.ru/vacancies/66511453?host=hh.ru', 'adv_response_url': 'https://api.hh.ru/vacancies/66511453/adv_response?host=hh.ru', 'alternate_url': 'https://hh.ru/vacancy/66511453', 'relations': [], 'employer': {'id': '3306967', 'name': 'Mind&Machine', 'url': 'https://api.hh.ru/employers/3306967', 'alternate_url': 'https://hh.ru/employer/3306967', 'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/948233.jpg', '240': 'https://hhcdn.ru/employer-logo/4233469.jpeg', '90': 'https://hhcdn.ru/employer-logo/4233468.jpeg'}, 'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3306967', 'trusted': True}, 'snippet': {'requirement': 'Ключевые навыки:\u200d\u200d. — Умение общаться с клиентами и понимать их бизнес-процессы. — Знание Python, в том числе numpy, scipy, pandas, scikit...', 'responsibility': 'анализ процессов клиентов. — прогнозирование временных рядов: потока клиентов, объёма операций, построение иерархических временных рядов. — разработка и улучшение алгоритмов дискретной оптимизации.'}, 'contacts': None, 'schedule': {'id': 'fullDay', 'name': 'Полный день'}, 'working_days': [], 'working_time_intervals': [], 'working_time_modes': [], 'accept_temporary': True}, {'id': '66632053', 'premium': False, 'name': 'Senior Data Scientist', 'department': None, 'has_test': False, 'response_letter_required': False, 'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'}, 'salary': {'from': 4000, 'to': 5000, 'currency': 'USD', 'gross': True}, 'type ...

# %%
r.json()

# %%
url = 'https://api.hh.ru/vacancies?text=&vac_id=&city=Moscow'
r = requests.get(url)
r.status_code

# %%
r.json()
